# %%
# !pip install craft-text-detector
# Out:
# Collecting craft-text-detector
#   Downloading craft_text_detector-0.4.3-py3-none-any.whl (18 kB)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from craft-text-detector) (1.12.0)
# Requirement already satisfied: torchvision>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from craft-text-detector) (0.13.0)
# Collecting opencv-python<4.5.4.62,>=3.4.8.29 (from craft-text-detector)
#   Downloading opencv_python-4.5.4.60-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (60.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.3/60.3 MB 11.9 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from craft-text-detector) (1.11.4)
# Requirement already satisfied: gdown>=3.10.1 in /usr/local/lib/python3.10/dist-packages (from craft-text-detector) (4.6.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown>=3.10.1->craft-text-detector) (3.13.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown>=3.10.1->craft-text-detector) (2.31.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from gdown>=3.10.1->craft-text-detector) (1.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown>=3.10.1->craft-text-detector) (4.66.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown>=3.10.1->craft-text-detector) (4.11.2)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python<4.5.4.62,>=3.4.8.29->craft-text-detector) (1.23.5)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->craft-text-detector) (4.5.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision>=0.7.0->craft-text-detector) (9.4.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown>=3.10.1->craft-text-detector) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown>=3.10.1->craft-text-detector) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown>=3.10.1->craft-text-detector) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown>=3.10.1->craft-text-detector) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown>=3.10.1->craft-text-detector) (2023.11.17)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown>=3.10.1->craft-text-detector) (1.7.1)
# Installing collected packages: opencv-python, craft-text-detector
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.8.0.76
#     Uninstalling opencv-python-4.8.0.76:
#       Successfully uninstalled opencv-python-4.8.0.76
# Successfully installed craft-text-detector-0.4.3 opencv-python-4.5.4.60

# %%
import torch
import cv2
from craft_text_detector import Craft

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
image_path ='/content/drive/MyDrive/CRAFT/input1.png'
output_dir = '/content/drive/MyDrive/CRAFT'

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
plt.rcParams["axes.grid"] = False
image = mpimg.imread(image_path)
plt.imshow(image)

# %%
def detect(image_path,output_dir):
  # create a craft instance
  craft = Craft(output_dir=output_dir, crop_type="poly", cuda=False)

  # apply craft text detection and export detected regions to output directory
  prediction_result = craft.detect_text(image_path)

# %%
detect(image_path,output_dir)
# Out:
# /usr/local/lib/python3.10/dist-packages/craft_text_detector/craft_utils.py:415: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   polys = np.array(polys)
# /usr/local/lib/python3.10/dist-packages/craft_text_detector/predict.py:110: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   polys_as_ratio = np.array(polys_as_ratio)

# %%
# !pip uninstall -y torchaudio torchdata torchtext
# Out:
# Found existing installation: torchaudio 2.1.0+cu121
# Uninstalling torchaudio-2.1.0+cu121:
#   Successfully uninstalled torchaudio-2.1.0+cu121
# Found existing installation: torchdata 0.7.0
# Uninstalling torchdata-0.7.0:
#   Successfully uninstalled torchdata-0.7.0
# Found existing installation: torchtext 0.16.0
# Uninstalling torchtext-0.16.0:
#   Successfully uninstalled torchtext-0.16.0

# %%
# !pip install torch==1.12.0 torchvision==0.13.0
# Out:
# Collecting torch==1.12.0
#   Downloading torch-1.12.0-cp310-cp310-manylinux1_x86_64.whl (776.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.3/776.3 MB 2.1 MB/s eta 0:00:00
# Collecting torchvision==0.13.0
#   Downloading torchvision-0.13.0-cp310-cp310-manylinux1_x86_64.whl (19.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.1/19.1 MB 44.5 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==1.12.0) (4.5.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision==0.13.0) (1.23.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision==0.13.0) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision==0.13.0) (9.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.13.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.13.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.13.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.13.0) (2023.11.17)
# Installing collected packages: torch, torchvision
#   Attempting uninstall: torch
#     Found existing installation: torch 2.1.0+cu121
#     Uninstalling torch-2.1.0+cu121:
#       Successfully uninstalled torch-2.1.0+cu121
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.16.0+cu121
#     Uninstalling torchvision-0.16.0+cu121:
#       Successfully uninstalled torchvision-0.16.0+cu121
# Successfully installed torch-1.12.0 torchvision-0.13.0

# %%
import torch
import torchvision.models as models

# %%
vgg_model_urls = models.vgg.model_urls
print(vgg_model_urls)
# Out:
# {'vgg11': 'https://download.pytorch.org/models/vgg11-8a719046.pth', 'vgg13': 'https://download.pytorch.org/models/vgg13-19584684.pth', 'vgg16': 'https://download.pytorch.org/models/vgg16-397923af.pth', 'vgg19': 'https://download.pytorch.org/models/vgg19-dcbb9e9d.pth', 'vgg11_bn': 'https://download.pytorch.org/models/vgg11_bn-6002323d.pth', 'vgg13_bn': 'https://download.pytorch.org/models/vgg13_bn-abd245e5.pth', 'vgg16_bn': 'https://download.pytorch.org/models/vgg16_bn-6c64b313.pth', 'vgg19_bn': 'https://download.pytorch.org/models/vgg19_bn-c79401a0.pth'}

# %%
import glob
from IPython.display import Image

image_paths = glob.glob('/content/drive/MyDrive/CRAFT/*.png')
print(image_paths)
Image(image_paths[3])
# Out:
# ['/content/drive/MyDrive/CRAFT/input1.png', '/content/drive/MyDrive/CRAFT/input1_text_score_heatmap.png', '/content/drive/MyDrive/CRAFT/input1_link_score_heatmap.png', '/content/drive/MyDrive/CRAFT/input1_text_detection.png']
